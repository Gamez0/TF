# %% [markdown]
# <a href="https://colab.research.google.com/github/Gamez0/TensorFlow2.0/blob/main/tf2_02_1_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf

# %%
x_train=[1,2,3,4]
y_train=[1,2,3,4]

# %%
tf.model = tf.keras.Sequential()
# units == output shape, input_dim == input shape
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=1))

# %%
sgd = tf.keras.optimizers.SGD(lr=0.1) # SGD == standard gradient descendent, lr == learning rate
tf.model.compile(loss='mse',optimizer=sgd) # mse == mean_squared_error, 1/m * sig(y'-y)^2

# %%
# prints summary of the model to the terminal
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.model.fit(x_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 1ms/step - loss: 20.9981
# Epoch 2/200
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6132
# Epoch 3/200
# 1/1 [==============================] - 0s 993us/step - loss: 4.4907
# Epoch 4/200
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1804
# Epoch 5/200
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1335
# Epoch 6/200
# 1/1 [==============================] - 0s 961us/step - loss: 0.6543
# Epoch 7/200
# 1/1 [==============================] - 0s 973us/step - loss: 0.4306
# Epoch 8/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3221
# Epoch 9/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2658
# Epoch 10/200
# 1/1 [==============================] - 0s 955us/step - loss: 0.2334
# Epoch 11/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2121
# Epoch 12/200
# 1/1 [==============================] - 0s 979us/step - loss: 0.1962
# ...

# %%
y_predict = tf.model.predict(np.array([1,2]))
print(y_predict)
# Out:
# [[1.0022699]
#  [2.0010998]]
